# %%
 import pandas as pd
dataset_1 = []

path = "Pattern-DataSet\EXTENDED_1.xlsx"
dataset_1.append(pd.read_excel(path))

column_name_dataset_1 =[
    'Timestamp', 'Score', 'ID', 'Gender', 'Height', 'Weight', 'CGPA',
       'Daily spent time in social media (hour)', 'Hometown',
       'How many days in a week you feel more energetic',
       'Favorite transport mode', 'Favorite food names',
       'Expected food price of that favorite food',
       'Month cost for that particular food',
       'What do you like home delivery or eat in the restaurant',
       'University travel cost monthly', 'Hobby', 'Travel package you prefer',
       'Sickness-frequency in a month',
       'Favorite food in summer/winter/rainy season', 'Food flavor',
       'Hangout location(Spend most of the time)', 'Typically you go out with',
       'Travel budget', 'favourite restaurant', 'Unnamed: 25',
       'Restaurant location', 'Live with family(y/n)',
       'Are you happy with current situation?',
       'Number of programming hours spent per day', 'Sleep duration',
       'Do you start your day by planning(y/n)',
       'Do you have online shopping experience (y/n)',
       'Do you use products for grooming(y/n)',
       'Favourite food in rainy season', 'Prefers(food_quality/environment)',
       'No of time home delivery over a month(Number)',
       'No of time goes to restaurant over a month( n umber)',
       'Pickup location of yours for bus', 'Pickup time of yours for bus',
       'Your bank name', 'Preferred shopping area',
       'Monthly frequencies of shopping',
       'Do you prefer to play in Gaming Zone ?', 'Are you fashion active',
       'Which colour do you prefer(red/yellow)?',
       'Which cloths do you choose to wear(urban/linen shirt and trousers/jeans&shirt)?',
       'Do you feel low seeing other people"s achievement on social media',
       'Recently how many of your family members/neighbours affected by dengue',
       'do you find bargaining pleasing?',
       'Actual motive behind your future goal?',
       'Would you still pursue your goal if the motive behind it is fulfilled in another way?',
       'Do you think it is a good idea to go to a well known shop just for the sake of social status?why?',
       'How much do you earn monthly?', 'Wake up time?',
       'When is your class starting time', 'When is your class ending time',
       'What do you love most?', 'Are you satisfied with your country’s law?',
       'Which law do you prefer more?',
       'What’s your view about law enforcement groups?',
       'Are you eager to harm yourself to defend your beliefs?',
       'How frequently you visit a doctor within a year"',
       'How many people do you follow on social media?',
       'How much time you spend in university without academic curriculum(in hour)?',
       'Are you rich in vocabulary?',
       'Class note taking tendency(High,Low,Medium)',
       'Theory class attendance(h,l,m)', 'Theory class interest(h,l,m)',
       'Lab interest(h,l,m)',
       'Preference(class lectures cl or online tutorials)'
]

# %%
dataset_2 = []

path = "Pattern-DataSet\Extended_version_3.xlsx"
dataset_2.append(pd.read_excel(path))

column_name_dataset_2 =[
    'Timestamp','Total score','ID','ID [Score]','ID [Feedback]','what kind of foods you generally eat in the breakfast time?',
    'what kind of foods you generally eat in the breakfast time? [Score]',
    'what kind of foods you generally eat in the breakfast time? [Feedback]','number of private tuition or part time activities',
    'number of private tuition or part time activities [Score]','number of private tuition or part time activities [Feedback]',
    'where he/she has spent their childhood(city/countryside)','where he/she has spent their childhood(city/countryside) [Score]',
    'where he/she has spent their childhood(city/countryside) [Feedback]','favourite destination(mountain/sea/forest)',
    'favourite destination(mountain/sea/forest) [Score]','favourite destination(mountain/sea/forest) [Feedback]',
    'Do you follow proper diet chart ?(y/n)','Do you follow proper diet chart ?(y/n) [Score]',
    'Do you follow proper diet chart ?(y/n) [Feedback]','Do you frequently eat fast foods  ? (y/n)',
    'Do you frequently eat fast foods  ? (y/n) [Score]','Do you frequently eat fast foods  ? (y/n) [Feedback]',
    'Do you exercise ? (everyday/never/sometimes )','Do you exercise ? (everyday/never/sometimes ) [Score]',
    'Do you exercise ? (everyday/never/sometimes ) [Feedback]',
    'How much you prefer to spend when you are going out for dinner or lunch ?( 200-300,400-600,700-1000,1000+)',
    'How much you prefer to spend when you are going out for dinner or lunch ?( 200-300,400-600,700-1000,1000+) [Score]',
    'How much you prefer to spend when you are going out for dinner or lunch ?( 200-300,400-600,700-1000,1000+) [Feedback]',
    'Number of diabetic affected family members','Number of diabetic affected family members [Score]',
    'Number of diabetic affected family members [Feedback]','Blood pressure: a)High b)Normal c)Low',
    'Blood pressure: a)High b)Normal c)Low [Score]','Blood pressure: a)High b)Normal c)Low [Feedback]',
    'Waist Circumference(cm) (a) less than 80 (b) 80-94 (c) 94-102 (d) greater than 102',
    'Waist Circumference(cm) (a) less than 80 (b) 80-94 (c) 94-102 (d) greater than 102 [Score]',
    'Waist Circumference(cm) (a) less than 80 (b) 80-94 (c) 94-102 (d) greater than 102 [Feedback]',
    'Do you feel yourself depressed in a hostile situation?','Do you feel yourself depressed in a hostile situation? [Score]',
    'Do you feel yourself depressed in a hostile situation? [Feedback]','Do you feel insecure among the strangers?',
    'Do you feel insecure among the strangers? [Score]','Do you feel insecure among the strangers? [Feedback]',
    'Are you impatient in general?','Are you impatient in general? [Score]','Are you impatient in general? [Feedback]',
    'Do you feel confident when you start any project?','Do you feel confident when you start any project? [Score]',
    'Do you feel confident when you start any project? [Feedback]','Are you helpful towards your family & friends?',
    'Are you helpful towards your family & friends? [Score]','Are you helpful towards your family & friends? [Feedback]',
    'Do you like listening songs?','Do you like listening songs? [Score]','Do you like listening songs? [Feedback]',
    'Do you get angry instantly if anything goes wrong?','Do you get angry instantly if anything goes wrong? [Score]',
    'Do you get angry instantly if anything goes wrong? [Feedback]','(a) iPhone or (b) other smartphone?',
    '(a) iPhone or (b) other smartphone? [Score]','(a) iPhone or (b) other smartphone? [Feedback]',
    'Do you agree with this statement? - "Look does not matter" a)Yes b)No',
    'Do you agree with this statement? - "Look does not matter" a)Yes b)No [Score]',
    'Do you agree with this statement? - "Look does not matter" a)Yes b)No [Feedback]',
    'Mobile games are- a)fun and interesting b) boring and waste of time c) do not care',
    'Mobile games are- a)fun and interesting b) boring and waste of time c) do not care [Score]',
    'Mobile games are- a)fun and interesting b) boring and waste of time c) do not care [Feedback]',
    'Favorite mobile game genre is- a) War game b) Racing c) Puzzle','Favorite mobile game genre is- a) War game b) Racing c) Puzzle [Score]',
    'Favorite mobile game genre is- a) War game b) Racing c) Puzzle [Feedback]','study time (hour)','study time (hour) [Score]',
    'study time (hour) [Feedback]'
]

# %%
dataset_3 = []

path = "Pattern-DataSet\Extended_version_2.xlsx"
dataset_3.append(pd.read_excel(path))

column_name_dataset_3 =[
    'Timestamp','Total score','ID','ID [Score]','ID [Feedback]','I try to do better than what is expected from me',
    'I try to do better than what is expected from me [Score]','I try to do better than what is expected from me [Feedback]',
    ' If I get more change, I return',' If I get more change, I return [Score]',' If I get more change, I return [Feedback]',
    'Its no use worrying about public affairs.','Its no use worrying about public affairs.  [Score]',
    'Its no use worrying about public affairs.  [Feedback]','Are you a book lover?','Are you a book lover? [Score]',
    'Are you a book lover? [Feedback]','Is there any book store in your area?','Is there any book store in your area? [Score]',
    'Is there any book store in your area? [Feedback]','Blood type.','Blood type. [Score]','Blood type. [Feedback]',
    'Being introverted or extroverted.','Being introverted or extroverted. [Score]','Being introverted or extroverted. [Feedback]',
    'Concerned about life (a) or goes too easy on life (b).','Concerned about life (a) or goes too easy on life (b). [Score]',
    'Concerned about life (a) or goes too easy on life (b). [Feedback]','Estimated work time per day.',
    'Estimated work time per day. [Score]','Estimated work time per day. [Feedback]',
    'How much time YOU plays game daily(in average HOUR)?','How much time YOU plays game daily(in average HOUR)? [Score]',
    'How much time YOU plays game daily(in average HOUR)? [Feedback]','Budget for buying a laptop',
    'Budget for buying a laptop [Score]','Budget for buying a laptop [Feedback]',
    'Do you feel guilty if you use spare time to relax?','Do you feel guilty if you use spare time to relax? [Score]',
    'Do you feel guilty if you use spare time to relax? [Feedback]',
    'Do you need to win in order to derive enjoyment from games and sports?',
    'Do you need to win in order to derive enjoyment from games and sports? [Score]',
    'Do you need to win in order to derive enjoyment from games and sports? [Feedback]',
    'Do you often try to do more than one thing at a time?','Do you often try to do more than one thing at a time? [Score]',
    'Do you often try to do more than one thing at a time? [Feedback]','Do you find it difficult and frustrating to wait in line?',
    'Do you find it difficult and frustrating to wait in line? [Score]','Do you find it difficult and frustrating to wait in line? [Feedback]',
    'Are you more of a morning person?','Are you more of a morning person? [Score]','Are you more of a morning person? [Feedback]',
    'Would you consider yourself to be a perfectionist?','Would you consider yourself to be a perfectionist? [Score]',
    'Would you consider yourself to be a perfectionist? [Feedback]'
]

# %%
for data in dataset_1:
    data.columns = column_name_dataset_1

dataset_concat = pd.concat(dataset_1 , sort = False, ignore_index=True)
dataset_concat.to_csv("Pattern-DataSet\DATASET_ALL.csv" , index=False)
dataset_all = pd.read_csv("Pattern-DataSet\DATASET_ALL.csv")
column_name_dataset = [
    'ID','Gender','Daily spent time in social media (hour)','Are you happy with current situation?',
    'Do you start your day by planning(y/n)'
    
]
df = dataset_all[column_name_dataset]
df
# Out:
#             ID  Gender Daily spent time in social media (hour)  \
# 0    151341004     NaN                                     NaN
# 1    151341021    Male                     2019-05-02 00:00:00
# 2    151341012    Male                            Below 1 hour
# 3    151341008  Female                     2019-05-02 00:00:00
# 4    151341011    Male                     2019-05-02 00:00:00
# 5    151341029    Male                            Below 1 hour
# 6    151341005  Female                     2019-05-02 00:00:00
# 7    151341006  Female                            Above 5 hour
# 8    151341023  Female                     2019-05-02 00:00:00
# 9    151341009  Female                     2019-05-02 00:00:00
# 10   151341014    Male                     2019-05-02 00:00:00
# 11   151341026    Male                     2019-05-02 00:00:00
# 12   151341004    Male                            Below 1 hour
# 13   151341019    Male                     2019-05-02 00:00:00
# ...

# %%
for data in dataset_2:
    data.columns = column_name_dataset_2

dataset_concat2 = pd.concat(dataset_2 , sort = False, ignore_index=True)
dataset_concat2.to_csv("Pattern-DataSet\DATASET_ALL2.csv" , index=False)
dataset_all2 = pd.read_csv("Pattern-DataSet\DATASET_ALL2.csv")
column_name_dataset = [
     'ID','Blood pressure: a)High b)Normal c)Low','Do you feel yourself depressed in a hostile situation?',   
    'Do you feel confident when you start any project?'
]
dfs = dataset_all2[column_name_dataset]
dfs
# Out:
#            ID Blood pressure: a)High b)Normal c)Low  \
# 0   151341038                                   Low
# 1   151341011                                Normal
# 2   151340926                                Normal
# 3   151341008                                   Low
# 4   151340950                                  High
# 5   141440945                                Normal
# 6   151340938                                Normal
# 7   151340903                                   Low
# 8   151341006                                Normal
# 9   151341035                                Normal
# 10  151340910                                Normal
# 11  151340964                                Normal
# 12  151340905                                Normal
# 13  151341013                                Normal
# 14  151340985                                Normal
# 15  131440910                                Normal
# 16  151340990                                   Low
# ...

# %%
for data in dataset_3:
    data.columns = column_name_dataset_3

dataset_concat3 = pd.concat(dataset_3 , sort = False, ignore_index=True)
dataset_concat3.to_csv("Pattern-DataSet\DATASET_ALL3.csv" , index=False)
dataset_all3 = pd.read_csv("Pattern-DataSet\DATASET_ALL3.csv")
column_name_dataset = [
     'ID','I try to do better than what is expected from me','Concerned about life (a) or goes too easy on life (b).',
    'Estimated work time per day.','Do you feel guilty if you use spare time to relax?',
    'Do you need to win in order to derive enjoyment from games and sports?',
    'Do you often try to do more than one thing at a time?','Do you find it difficult and frustrating to wait in line?',
    'Are you more of a morning person?','Would you consider yourself to be a perfectionist?'
]
dfsx = dataset_all3[column_name_dataset]
dfsx
# Out:
#             ID  I try to do better than what is expected from me  \
# 0    151341040                                              True
# 1    131440899                                              True
# 2    141440899                                              True
# 3    151341036                                             False
# 4    151341038                                              True
# 5    131440910                                              True
# 6    151341035                                              True
# 7    141440980                                              True
# 8    141340960                                             False
# 9    141440945                                              True
# 10   141440962                                              True
# 11   141340900                                             False
# 12   151341031                                             False
# ...

# %%
result = pd.merge(df, dfs,how='outer')

# %%
new_result = pd.merge(result,dfsx,how='outer')

# %%
f_result = new_result.dropna()

# %%
f_result
# Out:
#             ID  Gender Daily spent time in social media (hour)  \
# 1    151341004    Male                            Below 1 hour
# 2    151341021    Male                     2019-05-02 00:00:00
# 3    151341012    Male                            Below 1 hour
# 4    151341008  Female                     2019-05-02 00:00:00
# 5    151341011    Male                     2019-05-02 00:00:00
# 6    151341029    Male                            Below 1 hour
# 7    151341005  Female                     2019-05-02 00:00:00
# 8    151341006  Female                            Above 5 hour
# 9    151341023  Female                     2019-05-02 00:00:00
# 10   151341009  Female                     2019-05-02 00:00:00
# 11   151341014    Male                     2019-05-02 00:00:00
# 12   151341026    Male                     2019-05-02 00:00:00
# 14   151341013    Male                            Below 1 hour
# 15   151341022    Male                            Above 5 hour
# ...

# %%
f_result.to_csv('Dataset_n.csv', header=False, index=False)

# %%
'Gender','Blood pressure: a)High b)Normal c)Low','I try to do better than what is expected from me',
                    'Concerned about life (a) or goes too easy on life (b).','Do you feel guilty if you use spare time to relax?',
    'Do you need to win in order to derive enjoyment from games and sports?',
    'Do you often try to do more than one thing at a time?','Do you find it difficult and frustrating to wait in line?',
    'Are you more of a morning person?','Would you consider yourself to be a perfectionist?'
